# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Krho = 1.0 = a
# Kalpha = 2.0 = b
# Kbeta = -1.5 = c
file_path = 'C:/Users/Adlina/Desktop/Master in THD/SEM 1 Summer 23_24/Advanced Robotics/Recorded Data Nominal/'

# %%
# Krho=a, Kalpha=b, Kbeta=-0.5-4.0
file_pathA = 'Krho=a, Kalpha=b, Kbeta=-0.5/'
file_name1 = '3wrobotNI_N_CTRL_ab-0.5.csv'
file_name2 = '3wrobotNI_N_CTRL_ab-1.0.csv'
file_name3 = '3wrobotNI_N_CTRL_ab-2.0.csv'
file_name4 = '3wrobotNI_N_CTRL_ab-3.0.csv'
file_name5 = '3wrobotNI_N_CTRL_ab-4.0.csv'

# %%
# Krho=0.5-1.8, Kalpha=b, Kbeta=c
file_pathA = 'Krho=0.5, Kalpha=b, Kbeta=c/'
file_name1 = '3wrobotNI_N_CTRL_0.5bc.csv'
file_name2 = '3wrobotNI_N_CTRL_0.8bc.csv'
file_name3 = '3wrobotNI_N_CTRL_1.0bc.csv'
file_name4 = '3wrobotNI_N_CTRL_1.3bc.csv'
file_name5 = '3wrobotNI_N_CTRL_1.5bc.csv'
file_name6 = '3wrobotNI_N_CTRL_1.8bc.csv'
file_path6 = "".join([file_path, file_pathA, file_name6])
df6 = pd.read_csv(file_path6, skiprows=15)

# %%
# Krho=a, Kalpha=1.5-5.0, Kbeta=c
file_pathA = 'Krho=a, Kalpha=1.5, Kbeta=c/'
file_name1 = '3wrobotNI_N_CTRL_a1.5c.csv'
file_name2 = '3wrobotNI_N_CTRL_a2.5c.csv'
file_name3 = '3wrobotNI_N_CTRL_a3.0c.csv'
file_name4 = '3wrobotNI_N_CTRL_a4.0c.csv'
file_name5 = '3wrobotNI_N_CTRL_a5.0c.csv'

# %%
file_path1 = "".join([file_path, file_pathA, file_name1])
file_path2 = "".join([file_path, file_pathA, file_name2])
file_path3 = "".join([file_path, file_pathA, file_name3])
file_path4 = "".join([file_path, file_pathA, file_name4])
file_path5 = "".join([file_path, file_pathA, file_name5])

df1 = pd.read_csv(file_path1, skiprows=15)
df2 = pd.read_csv(file_path2, skiprows=15)
df3 = pd.read_csv(file_path3, skiprows=15)
df4 = pd.read_csv(file_path4, skiprows=15)
df5 = pd.read_csv(file_path5, skiprows=15)

# %%
# df1.head(5)
# df5.tail(5)
# df1.info()
# df5.describe()

# %%
# Plot settings
fig = plt.figure(figsize=(14, 10))

# Plot Trajectory (top-left)
plt.subplot(2, 2, 1)
plt.plot(df1['x [m]'], df1['y [m]'], 'b-', lw=0.8, label='Kbeta=-0.5')
plt.plot(df2['x [m]'], df2['y [m]'], 'g-', lw=0.8, label='Kbeta=-1.0')
plt.plot(df3['x [m]'], df3['y [m]'], 'r-', lw=0.8, label='Kbeta=-2.0')
plt.plot(df4['x [m]'], df4['y [m]'], 'c-', lw=0.8, label='Kbeta=3.0')
plt.plot(df5['x [m]'], df5['y [m]'], 'm-', lw=0.8, label='Kbeta=-4.0')
plt.scatter(df1['x [m]'].iloc[0], df1['y [m]'].iloc[0], marker='o', color='g', lw=0.8, label='Start')
plt.scatter(0, 0, marker='x', color='r', label='End')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.title('Trajectory')
plt.legend()
plt.grid()
plt.xlim(-4, 4)
plt.ylim(-4, 4)

# Plot Norm and Alpha (top-right)
plt.subplot(2, 2, 2)
plt.plot(df1['t [s]'], np.linalg.norm([df1['x [m]'], df1['y [m]']], axis=0), 'b--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kbeta=-0.5)')
plt.plot(df1['t [s]'], df1['alpha [rad]'], 'b-', lw=0.8, label=r'$\alpha$ [rad] (Kbeta=-0.5)')
plt.plot(df2['t [s]'], np.linalg.norm([df2['x [m]'], df2['y [m]']], axis=0), 'g--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kbeta=-1.0)')
plt.plot(df2['t [s]'], df2['alpha [rad]'], 'g-', lw=0.8, label=r'$\alpha$ [rad] (Kbeta=-1.0)')
plt.plot(df3['t [s]'], np.linalg.norm([df3['x [m]'], df3['y [m]']], axis=0), 'r--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kbeta=-2.0)')
plt.plot(df3['t [s]'], df3['alpha [rad]'], 'r-', lw=0.8, label=r'$\alpha$ [rad] (Kbeta=-2.0)')
plt.plot(df4['t [s]'], np.linalg.norm([df4['x [m]'], df4['y [m]']], axis=0), 'c--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kbeta=3.0)')
plt.plot(df4['t [s]'], df4['alpha [rad]'], 'c-', lw=0.8, label=r'$\alpha$ [rad] (Kbeta=3.0)')
plt.plot(df5['t [s]'], np.linalg.norm([df5['x [m]'], df5['y [m]']], axis=0), 'm--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kbeta=-4.0)')
plt.plot(df5['t [s]'], df5['alpha [rad]'], 'm-', lw=0.8, label=r'$\alpha$ [rad] (Kbeta=-4.0)')
plt.xlabel('t [s]')
plt.title('Robot Solution')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.ylim(-11, 11)

# Plot Accumulated Cost
plt.subplot(2, 2, 3)
plt.plot(df1['t [s]'], df1['accum_obj'], 'b--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kbeta=-0.5)')
plt.plot(df2['t [s]'], df2['accum_obj'], 'g--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kbeta=-1.0)')
plt.plot(df3['t [s]'], df3['accum_obj'], 'r--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kbeta=-2.0)')
plt.plot(df4['t [s]'], df4['accum_obj'], 'c--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kbeta=3.0)')
plt.plot(df5['t [s]'], df5['accum_obj'], 'm--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kbeta=-4.0)')
plt.xlabel('t [s]')
plt.title('Cost Functions')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.yticks([10**i for i in range(2, 7)])  # Set y-axis ticks at powers of 10 from 10^0 to 10^6

# Plot Control inputs
plt.subplot(2, 2, 4)
plt.plot(df1['t [s]'], df1['v [m/s]'], 'b-', lw=0.8, label='v [m/s] (Kbeta=-0.5)')
plt.plot(df1['t [s]'], df1['omega [rad/s]'], 'b--', lw=0.8, label=r'$\omega$ [rad/s] (Kbeta=-0.5)')
plt.plot(df2['t [s]'], df2['v [m/s]'], 'g-', lw=0.8, label='v [m/s] (Kbeta=-1.0)')
plt.plot(df2['t [s]'], df2['omega [rad/s]'], 'g--', lw=0.8, label=r'$\omega$ [rad/s] (Kbeta=-1.0)')
plt.plot(df3['t [s]'], df3['v [m/s]'], 'r-', lw=0.8, label='v [m/s] (Kbeta=-2.0)')
plt.plot(df3['t [s]'], df3['omega [rad/s]'], 'r--', lw=0.8, label=r'$\omega$ [rad/s] (Kbeta=-2.0)')
plt.plot(df4['t [s]'], df4['v [m/s]'], 'c-', lw=0.8, label='v [m/s] (Kbeta=3.0)')
plt.plot(df4['t [s]'], df4['omega [rad/s]'], 'c--', lw=0.8, label=r'$\omega$ [rad/s] (Kbeta=3.0)')
plt.plot(df5['t [s]'], df5['v [m/s]'], 'm-', lw=0.8, label='v [m/s] (Kbeta=-4.0)')
plt.plot(df5['t [s]'], df5['omega [rad/s]'], 'm--', lw=0.8, label=r'$\omega$ [rad/s] (Kbeta=-4.0)')
plt.xlabel('t [s]')
plt.title('Control Input')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.ylim(-4, 4)

plt.tight_layout()
plt.show()

# %%
# Plot settings
fig = plt.figure(figsize=(14, 10))

# Plot Trajectory (top-left)
plt.subplot(2, 2, 1)
plt.plot(df1['x [m]'], df1['y [m]'], 'b-', lw=0.8, label='Krho=0.5')
plt.plot(df2['x [m]'], df2['y [m]'], 'g-', lw=0.8, label='Krho=0.8')
plt.plot(df3['x [m]'], df3['y [m]'], 'r-', lw=0.8, label='Krho=1.0')
plt.plot(df4['x [m]'], df4['y [m]'], 'c-', lw=0.8, label='Krho=1.3')
plt.plot(df5['x [m]'], df5['y [m]'], 'm-', lw=0.8, label='Krho=1.5')
plt.plot(df6['x [m]'], df6['y [m]'], 'y-', lw=0.8, label='Krho=1.8')
plt.scatter(df1['x [m]'].iloc[0], df1['y [m]'].iloc[0], marker='o', color='g', lw=0.8, label='Start')
plt.scatter(0, 0, marker='x', color='r', label='End')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.title('Trajectory')
plt.legend()
plt.grid()
plt.xlim(-4, 4)
plt.ylim(-4, 4)

# Plot Norm and Alpha (top-right)
plt.subplot(2, 2, 2)
plt.plot(df1['t [s]'], np.linalg.norm([df1['x [m]'], df1['y [m]']], axis=0), 'b--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Krho=0.5)')
plt.plot(df1['t [s]'], df1['alpha [rad]'], 'b-', lw=0.8, label=r'$\alpha$ [rad] (Krho=0.5)')
plt.plot(df2['t [s]'], np.linalg.norm([df2['x [m]'], df2['y [m]']], axis=0), 'g--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Krho=0.8)')
plt.plot(df2['t [s]'], df2['alpha [rad]'], 'g-', lw=0.8, label=r'$\alpha$ [rad] (Krho=0.8)')
plt.plot(df3['t [s]'], np.linalg.norm([df3['x [m]'], df3['y [m]']], axis=0), 'r--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Krho=1.0)')
plt.plot(df3['t [s]'], df3['alpha [rad]'], 'r-', lw=0.8, label=r'$\alpha$ [rad] (Krho=1.0)')
plt.plot(df4['t [s]'], np.linalg.norm([df4['x [m]'], df4['y [m]']], axis=0), 'c--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Krho=1.3)')
plt.plot(df4['t [s]'], df4['alpha [rad]'], 'c-', lw=0.8, label=r'$\alpha$ [rad] (Krho=1.3)')
plt.plot(df5['t [s]'], np.linalg.norm([df5['x [m]'], df5['y [m]']], axis=0), 'm--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Krho=1.5)')
plt.plot(df5['t [s]'], df5['alpha [rad]'], 'm-', lw=0.8, label=r'$\alpha$ [rad] (Krho=1.5)')
plt.plot(df6['t [s]'], np.linalg.norm([df6['x [m]'], df6['y [m]']], axis=0), 'y--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Krho=1.8)')
plt.plot(df6['t [s]'], df6['alpha [rad]'], 'y-', lw=0.8, label=r'$\alpha$ [rad] (Krho=1.8)')
plt.xlabel('t [s]')
plt.title('Robot Solution')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.ylim(-11, 11)

# Plot Accumulated Cost
plt.subplot(2, 2, 3)
plt.plot(df1['t [s]'], df1['accum_obj'], 'b--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Krho=0.5)')
plt.plot(df2['t [s]'], df2['accum_obj'], 'g--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Krho=0.8)')
plt.plot(df3['t [s]'], df3['accum_obj'], 'r--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Krho=1.0)')
plt.plot(df4['t [s]'], df4['accum_obj'], 'c--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Krho=1.3)')
plt.plot(df5['t [s]'], df5['accum_obj'], 'm--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Krho=1.5)')
plt.plot(df6['t [s]'], df6['accum_obj'], 'y--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Krho=1.8)')
plt.xlabel('t [s]')
plt.title('Cost Functions')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.yticks([10**i for i in range(0, 7)])  # Set y-axis ticks at powers of 10 from 10^0 to 10^6

# Plot Control inputs
plt.subplot(2, 2, 4)
plt.plot(df1['t [s]'], df1['v [m/s]'], 'b-', lw=0.8, label='v [m/s] (Krho=0.5)')
plt.plot(df1['t [s]'], df1['omega [rad/s]'], 'b--', lw=0.8, label=r'$\omega$ [rad/s] (Krho=0.5)')
plt.plot(df2['t [s]'], df2['v [m/s]'], 'g-', lw=0.8, label='v [m/s] (Krho=0.8)')
plt.plot(df2['t [s]'], df2['omega [rad/s]'], 'g--', lw=0.8, label=r'$\omega$ [rad/s] (Krho=0.8)')
plt.plot(df3['t [s]'], df3['v [m/s]'], 'r-', lw=0.8, label='v [m/s] (Krho=1.0)')
plt.plot(df3['t [s]'], df3['omega [rad/s]'], 'r--', lw=0.8, label=r'$\omega$ [rad/s] (Krho=1.0)')
plt.plot(df4['t [s]'], df4['v [m/s]'], 'c-', lw=0.8, label='v [m/s] (Krho=1.3)')
plt.plot(df4['t [s]'], df4['omega [rad/s]'], 'c--', lw=0.8, label=r'$\omega$ [rad/s] (Krho=1.3)')
plt.plot(df5['t [s]'], df5['v [m/s]'], 'm-', lw=0.8, label='v [m/s] (Krho=1.5)')
plt.plot(df5['t [s]'], df5['omega [rad/s]'], 'm--', lw=0.8, label=r'$\omega$ [rad/s] (Krho=1.5)')
plt.plot(df6['t [s]'], df6['v [m/s]'], 'y-', lw=0.8, label='v [m/s] (Krho=1.8)')
plt.plot(df6['t [s]'], df6['omega [rad/s]'], 'y--', lw=0.8, label=r'$\omega$ [rad/s] (Krho=1.8)')
plt.xlabel('t [s]')
plt.title('Control Input')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.ylim(-4, 4)

plt.tight_layout()
plt.show()

# %%
# Plot settings
fig = plt.figure(figsize=(14, 10))

# Plot Trajectory (top-left)
plt.subplot(2, 2, 1)
plt.plot(df1['x [m]'], df1['y [m]'], 'b-', lw=0.8, label='Kalpha=1.5')
plt.plot(df2['x [m]'], df2['y [m]'], 'g-', lw=0.8, label='Kalpha=2.5')
plt.plot(df3['x [m]'], df3['y [m]'], 'r-', lw=0.8, label='Kalpha=3.0')
plt.plot(df4['x [m]'], df4['y [m]'], 'c-', lw=0.8, label='Kalpha=4.0')
plt.plot(df5['x [m]'], df5['y [m]'], 'm-', lw=0.8, label='Kalpha=5.0')
plt.scatter(df1['x [m]'].iloc[0], df1['y [m]'].iloc[0], marker='o', color='g', lw=0.8, label='Start')
plt.scatter(0, 0, marker='x', color='r', label='End')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.title('Trajectory')
plt.legend()
plt.grid()
plt.xlim(-4, 4)
plt.ylim(-4, 4)

# Plot Norm and Alpha (top-right)
plt.subplot(2, 2, 2)
plt.plot(df1['t [s]'], np.linalg.norm([df1['x [m]'], df1['y [m]']], axis=0), 'b--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kalpha=1.5)')
plt.plot(df1['t [s]'], df1['alpha [rad]'], 'b-', lw=0.8, label=r'$\alpha$ [rad] (Kalpha=1.5)')
plt.plot(df2['t [s]'], np.linalg.norm([df2['x [m]'], df2['y [m]']], axis=0), 'g--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kalpha=2.5)')
plt.plot(df2['t [s]'], df2['alpha [rad]'], 'g-', lw=0.8, label=r'$\alpha$ [rad] (Kalpha=2.5)')
plt.plot(df3['t [s]'], np.linalg.norm([df3['x [m]'], df3['y [m]']], axis=0), 'r--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kalpha=3.0)')
plt.plot(df3['t [s]'], df3['alpha [rad]'], 'r-', lw=0.8, label=r'$\alpha$ [rad] (Kalpha=3.0)')
plt.plot(df4['t [s]'], np.linalg.norm([df4['x [m]'], df4['y [m]']], axis=0), 'c--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kalpha=4.0)')
plt.plot(df4['t [s]'], df4['alpha [rad]'], 'c-', lw=0.8, label=r'$\alpha$ [rad] (Kalpha=4.0)')
plt.plot(df5['t [s]'], np.linalg.norm([df5['x [m]'], df5['y [m]']], axis=0), 'm--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (Kalpha=5.0)')
plt.plot(df5['t [s]'], df5['alpha [rad]'], 'm-', lw=0.8, label=r'$\alpha$ [rad] (Kalpha=5.0)')
plt.xlabel('t [s]')
plt.title('Robot Solution')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.ylim(-11, 11)

# Plot Accumulated Cost
plt.subplot(2, 2, 3)
plt.plot(df1['t [s]'], df1['accum_obj'], 'b--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kalpha=1.5)')
plt.plot(df2['t [s]'], df2['accum_obj'], 'g--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kalpha=2.5)')
plt.plot(df3['t [s]'], df3['accum_obj'], 'r--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kalpha=3.0)')
plt.plot(df4['t [s]'], df4['accum_obj'], 'c--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kalpha=4.0)')
plt.plot(df5['t [s]'], df5['accum_obj'], 'm--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (Kalpha=5.0)')
plt.xlabel('t [s]')
plt.title('Cost Functions')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.yticks([10**i for i in range(0, 7)])  # Set y-axis ticks at powers of 10 from 10^0 to 10^6

# Plot Control inputs
plt.subplot(2, 2, 4)
plt.plot(df1['t [s]'], df1['v [m/s]'], 'b-', lw=0.8, label='v [m/s] (Kalpha=1.5)')
plt.plot(df1['t [s]'], df1['omega [rad/s]'], 'b--', lw=0.8, label=r'$\omega$ [rad/s] (Kalpha=1.5)')
plt.plot(df2['t [s]'], df2['v [m/s]'], 'g-', lw=0.8, label='v [m/s] (Kalpha=2.5)')
plt.plot(df2['t [s]'], df2['omega [rad/s]'], 'g--', lw=0.8, label=r'$\omega$ [rad/s] (Kalpha=2.5)')
plt.plot(df3['t [s]'], df3['v [m/s]'], 'r-', lw=0.8, label='v [m/s] (Kalpha=3.0)')
plt.plot(df3['t [s]'], df3['omega [rad/s]'], 'r--', lw=0.8, label=r'$\omega$ [rad/s] (Kalpha=3.0)')
plt.plot(df4['t [s]'], df4['v [m/s]'], 'c-', lw=0.8, label='v [m/s] (Kalpha=4.0)')
plt.plot(df4['t [s]'], df4['omega [rad/s]'], 'c--', lw=0.8, label=r'$\omega$ [rad/s] (Kalpha=4.0)')
plt.plot(df5['t [s]'], df5['v [m/s]'], 'm-', lw=0.8, label='v [m/s] (Kalpha=5.0)')
plt.plot(df5['t [s]'], df5['omega [rad/s]'], 'm--', lw=0.8, label=r'$\omega$ [rad/s] (Kalpha=5.0)')
plt.xlabel('t [s]')
plt.title('Control Input')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.ylim(-4, 4)

plt.tight_layout()
# plt.savefig('Nominal K Alpha')
plt.show()
