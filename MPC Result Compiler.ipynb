# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# N = 3, 6, 9
# R = A [10,100,10,0,0]
# R = B [100,10,10,0,0]
# R = C [10,10,100,0,0]
file_path = 'C:/Users/Adlina/Desktop/Master in THD/SEM 1 Summer 23_24/Advanced Robotics/Recorded Data MPC/'

# %%
# N=3, R=A [10,100,10,0,0]
file_pathA = 'N=3, R=A, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_3A0.1.csv'
file_name2 = '3wrobotNI_MPC_3A0.2.csv'
file_name3 = '3wrobotNI_MPC_3A0.3.csv'
file_name4 = '3wrobotNI_MPC_3A0.5.csv'
file_name5 = '3wrobotNI_MPC_3A1.0.csv'

# %%
# N=3, R=B
file_pathA = 'N=3, R=B, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_3B0.1.csv'
file_name2 = '3wrobotNI_MPC_3B0.2.csv'
file_name3 = '3wrobotNI_MPC_3B0.3.csv'
file_name4 = '3wrobotNI_MPC_3B0.5.csv'
file_name5 = '3wrobotNI_MPC_3B1.0.csv'

# %%
# N=3, R=C
file_path = 'C:/Users/Adlina/Desktop/Master in THD/SEM 1 Summer 23_24/Advanced Robotics/Recorded Data MPC/N=3, R=C, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_3C0.1.csv'
file_name2 = '3wrobotNI_MPC_3C0.2.csv'
file_name3 = '3wrobotNI_MPC_3C0.3.csv'
file_name4 = '3wrobotNI_MPC_3C0.5.csv'
file_name5 = '3wrobotNI_MPC_3C1.0.csv'

# %%
# N=6, R=A
file_pathA = 'N=6, R=A, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_6A0.1.csv'
file_name2 = '3wrobotNI_MPC_6A0.2.csv'
file_name3 = '3wrobotNI_MPC_6A0.3.csv'
file_name4 = '3wrobotNI_MPC_6A0.5.csv'
file_name5 = '3wrobotNI_MPC_6A1.0.csv'

# %%
# N=6, R=B
file_pathA = 'N=6, R=B, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_6B0.1.csv'
file_name2 = '3wrobotNI_MPC_6B0.2.csv'
file_name3 = '3wrobotNI_MPC_6B0.3.csv'
file_name4 = '3wrobotNI_MPC_6B0.5.csv'
file_name5 = '3wrobotNI_MPC_6B1.0.csv'

# %%
# N=6, R=C
file_path = 'C:/Users/Adlina/Desktop/Master in THD/SEM 1 Summer 23_24/Advanced Robotics/Recorded Data MPC/N=6, R=C, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_6C0.1.csv'
file_name2 = '3wrobotNI_MPC_6C0.2.csv'
file_name3 = '3wrobotNI_MPC_6C0.3.csv'
file_name4 = '3wrobotNI_MPC_6C0.5.csv'
file_name5 = '3wrobotNI_MPC_6C1.0.csv'

# %%
# N=9, R=A
file_pathA = 'N=9, R=A, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_9A0.1.csv'
file_name2 = '3wrobotNI_MPC_9A0.2.csv'
file_name3 = '3wrobotNI_MPC_9A0.3.csv'
file_name4 = '3wrobotNI_MPC_9A0.5.csv'
file_name5 = '3wrobotNI_MPC_9A1.0.csv'

# %%
# N=9, R=B
file_pathA = 'N=9, R=B, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_9B0.1.csv'
file_name2 = '3wrobotNI_MPC_9B0.2.csv'
file_name3 = '3wrobotNI_MPC_9B0.3.csv'
file_name4 = '3wrobotNI_MPC_9B0.5.csv'
file_name5 = '3wrobotNI_MPC_9B1.0.csv'

# %%
# N=9, R=C
file_path = 'C:/Users/Adlina/Desktop/Master in THD/SEM 1 Summer 23_24/Advanced Robotics/Recorded Data MPC/N=9, R=C, dt =0.1-1.0/'
file_name1 = '3wrobotNI_MPC_9C0.1.csv'
file_name2 = '3wrobotNI_MPC_9C0.2.csv'
file_name3 = '3wrobotNI_MPC_9C0.3.csv'
file_name4 = '3wrobotNI_MPC_9C0.5.csv'
file_name5 = '3wrobotNI_MPC_9C1.0.csv'

# %%
file_path1 = "".join([file_path, file_pathA, file_name1])
file_path2 = "".join([file_path, file_pathA, file_name2])
file_path3 = "".join([file_path, file_pathA, file_name3])
file_path4 = "".join([file_path, file_pathA, file_name4])
file_path5 = "".join([file_path, file_pathA, file_name5])

df1 = pd.read_csv(file_path1, skiprows=15)
df2 = pd.read_csv(file_path2, skiprows=15)
df3 = pd.read_csv(file_path3, skiprows=15)
df4 = pd.read_csv(file_path4, skiprows=15)
df5 = pd.read_csv(file_path5, skiprows=15)

# %%
# df1.head(5)
# df5.tail(5)
# df1.info()
# df5.describe()

# %%
# Plot settings
fig = plt.figure(figsize=(14, 10))

# Plot Trajectory (top-left)
plt.subplot(2, 2, 1)
plt.plot(df1['x [m]'], df1['y [m]'], 'b-', lw=0.8, label='dt=0.1')
plt.plot(df2['x [m]'], df2['y [m]'], 'g-', lw=0.8, label='dt=0.2')
plt.plot(df3['x [m]'], df3['y [m]'], 'r-', lw=0.8, label='dt=0.3')
plt.plot(df4['x [m]'], df4['y [m]'], 'c-', lw=0.8, label='dt=0.5')
plt.plot(df5['x [m]'], df5['y [m]'], 'm-', lw=0.8, label='dt=1.0')
plt.scatter(df1['x [m]'].iloc[0], df1['y [m]'].iloc[0], marker='o', color='lightgreen', label='Start')
plt.scatter(0, 0, marker='x', color='y', label='End')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.title('Trajectory')
plt.legend()
plt.grid()
plt.xlim(-4, 4)
plt.ylim(-4, 4)

# Plot Norm and Alpha (top-right)
plt.subplot(2, 2, 2)
plt.plot(df1['t [s]'], np.linalg.norm([df1['x [m]'], df1['y [m]']], axis=0), 'b--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (dt=0.1)')
plt.plot(df1['t [s]'], df1['alpha [rad]'], 'b-', lw=0.8, label=r'$\alpha$ [rad] (dt=0.1)')
plt.plot(df2['t [s]'], np.linalg.norm([df2['x [m]'], df2['y [m]']], axis=0), 'g--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (dt=0.2)')
plt.plot(df2['t [s]'], df2['alpha [rad]'], 'g-', lw=0.8, label=r'$\alpha$ [rad] (dt=0.2)')
plt.plot(df3['t [s]'], np.linalg.norm([df3['x [m]'], df3['y [m]']], axis=0), 'r--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (dt=0.3)')
plt.plot(df3['t [s]'], df3['alpha [rad]'], 'r-', lw=0.8, label=r'$\alpha$ [rad] (dt=0.3)')
plt.plot(df4['t [s]'], np.linalg.norm([df4['x [m]'], df4['y [m]']], axis=0), 'c--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (dt=0.5)')
plt.plot(df4['t [s]'], df4['alpha [rad]'], 'c-', lw=0.8, label=r'$\alpha$ [rad] (dt=0.5)')
plt.plot(df5['t [s]'], np.linalg.norm([df5['x [m]'], df5['y [m]']], axis=0), 'm--', lw=0.8, label=r'$\Vert(x,y)\Vert$ [m] (dt=1.0)')
plt.plot(df5['t [s]'], df5['alpha [rad]'], 'm-', lw=0.8, label=r'$\alpha$ [rad] (dt=1.0)')
plt.xlabel('t [s]')
plt.title('Robot Solution')
plt.legend(loc='upper right')
plt.grid()
plt.xlim(0, 30)
plt.ylim(-11, 11)

# Plot Accumulated Cost
plt.subplot(2, 2, 3)
plt.plot(df1['t [s]'], df1['accum_obj'], 'b--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.1)')
plt.plot(df2['t [s]'], df2['accum_obj'], 'g--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.2)')
plt.plot(df3['t [s]'], df3['accum_obj'], 'r--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.3)')
plt.plot(df4['t [s]'], df4['accum_obj'], 'c--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.5)')
plt.plot(df5['t [s]'], df5['accum_obj'], 'm--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=1.0)')
plt.xlabel('t [s]')
plt.title('Cost Functions')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.yticks([10**i for i in range(2, 7)])  # Set y-axis ticks at powers of 10 from 10^0 to 10^6

# Plot Control inputs
plt.subplot(2, 2, 4)
plt.plot(df1['t [s]'], df1['v [m/s]'], 'b-', lw=0.8, label='v [m/s] (dt=0.1)')
plt.plot(df1['t [s]'], df1['omega [rad/s]'], 'b--', lw=0.8, label=r'$\omega$ [rad/s] (dt=0.1)')
plt.plot(df2['t [s]'], df2['v [m/s]'], 'g-', lw=0.8, label='v [m/s] (dt=0.2)')
plt.plot(df2['t [s]'], df2['omega [rad/s]'], 'g--', lw=0.8, label=r'$\omega$ [rad/s] (dt=0.2)')
plt.plot(df3['t [s]'], df3['v [m/s]'], 'r-', lw=0.8, label='v [m/s] (dt=0.3)')
plt.plot(df3['t [s]'], df3['omega [rad/s]'], 'r--', lw=0.8, label=r'$\omega$ [rad/s] (dt=0.3)')
plt.plot(df4['t [s]'], df4['v [m/s]'], 'c-', lw=0.8, label='v [m/s] (dt=0.5)')
plt.plot(df4['t [s]'], df4['omega [rad/s]'], 'c--', lw=0.8, label=r'$\omega$ [rad/s] (dt=0.5)')
plt.plot(df5['t [s]'], df5['v [m/s]'], 'm-', lw=0.8, label='v [m/s] (dt=1.0)')
plt.plot(df5['t [s]'], df5['omega [rad/s]'], 'm--', lw=0.8, label=r'$\omega$ [rad/s] (dt=1.0)')
plt.xlabel('t [s]')
plt.title('Control Input')
plt.legend(loc='upper right')
plt.grid()
plt.xlim(0, 30)
plt.ylim(-4, 4)

plt.tight_layout()
plt.show()

# %%
# Plot settings
fig = plt.figure(figsize=(10, 10))

# Plot Trajectory (top-left)
plt.subplot(2, 2, 1)
plt.plot(df1['x [m]'], df1['y [m]'], 'b-', lw=0.8, label='dt=0.1')
plt.plot(df2['x [m]'], df2['y [m]'], 'g-', lw=0.8, label='dt=0.2')
plt.plot(df3['x [m]'], df3['y [m]'], 'r-', lw=0.8, label='dt=0.3')
plt.plot(df4['x [m]'], df4['y [m]'], 'c-', lw=0.8, label='dt=0.5')
plt.plot(df5['x [m]'], df5['y [m]'], 'm-', lw=0.8, label='dt=1.0')
plt.scatter(df1['x [m]'].iloc[0], df1['y [m]'].iloc[0], marker='o', color='lightgreen', label='Start')
plt.scatter(0, 0, marker='x', color='r', label='End')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.title('Trajectory')
plt.legend()
plt.grid()
plt.xlim(-4, 4)
plt.ylim(-4, 4)


# Plot Accumulated Cost
plt.subplot(2, 2, 2)
plt.plot(df1['t [s]'], df1['accum_obj'], 'b--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.1)')
plt.plot(df2['t [s]'], df2['accum_obj'], 'g--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.2)')
plt.plot(df3['t [s]'], df3['accum_obj'], 'r--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.3)')
plt.plot(df4['t [s]'], df4['accum_obj'], 'c--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.5)')
plt.plot(df5['t [s]'], df5['accum_obj'], 'm--', lw=0.8, label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=1.0)')
plt.xlabel('t [s]')
plt.title('Cost Functions')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.yticks([10**i for i in range(2, 7)])  # Set y-axis ticks at powers of 10 from 10^0 to 10^6

plt.tight_layout()
plt.show()
