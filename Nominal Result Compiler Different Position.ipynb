# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = 'C:/Users/Adlina/Desktop/Master in THD/SEM 1 Summer 23_24/Advanced Robotics/Recorded Data Nominal/'

# %%
# Krho=1.0, Kalpha=2.0, Kbeta=-1.5
file_pathA = 'Krho=1.0, Kalpha=2.0, Kbeta=-1.5/'
file_name1 = '3wrobotNI_N_CTRL_-3,-3.csv'
file_name2 = '3wrobotNI_N_CTRL_0,-3.csv'
file_name3 = '3wrobotNI_N_CTRL_3,-3.csv'
file_name4 = '3wrobotNI_N_CTRL_3,0.csv'
file_name5 = '3wrobotNI_N_CTRL_3,3.csv'
file_name6 = '3wrobotNI_N_CTRL_0,3.csv'
file_name7 = '3wrobotNI_N_CTRL_-3,3.csv'
file_name8 = '3wrobotNI_N_CTRL_-3,0.csv'

# %%
file_path1 = "".join([file_path, file_pathA, file_name1])
file_path2 = "".join([file_path, file_pathA, file_name2])
file_path3 = "".join([file_path, file_pathA, file_name3])
file_path4 = "".join([file_path, file_pathA, file_name4])
file_path5 = "".join([file_path, file_pathA, file_name5])
file_path6 = "".join([file_path, file_pathA, file_name6])
file_path7 = "".join([file_path, file_pathA, file_name7])
file_path8 = "".join([file_path, file_pathA, file_name8])

df1 = pd.read_csv(file_path1, skiprows=15)
df2 = pd.read_csv(file_path2, skiprows=15)
df3 = pd.read_csv(file_path3, skiprows=15)
df4 = pd.read_csv(file_path4, skiprows=15)
df5 = pd.read_csv(file_path5, skiprows=15)
df6 = pd.read_csv(file_path6, skiprows=15)
df7 = pd.read_csv(file_path7, skiprows=15)
df8 = pd.read_csv(file_path8, skiprows=15)

# %%
# df1.head(5)
# df5.tail(5)
# df1.info()
# df5.describe()

# %%
# Plot settings
fig = plt.figure(figsize=(14, 10))

# Plot Trajectory (top-left)
plt.subplot(2, 2, 1)
plt.plot(df1['x [m]'], df1['y [m]'], 'b-', lw=0.8)
plt.annotate(f'(-3, -3, 0.785)', (df1['x [m]'][0], df1['y [m]'][0]), textcoords="offset points", xytext=(0,-20), ha='center')
plt.plot(df2['x [m]'], df2['y [m]'], 'g-', lw=0.8)
plt.annotate(f'(0, -3, 1.57)', (df2['x [m]'][0], df2['y [m]'][0]), textcoords="offset points", xytext=(-10,-20), ha='center')
plt.plot(df3['x [m]'], df3['y [m]'], 'r-', lw=0.8)
plt.annotate(f'(3, -3, 2.355)', (df3['x [m]'][0], df3['y [m]'][0]), textcoords="offset points", xytext=(10,-20), ha='center')
plt.plot(df4['x [m]'], df4['y [m]'], 'c-', lw=0.8)
plt.annotate(f'(3, 0, 3.14)', (df4['x [m]'][0], df4['y [m]'][0]), textcoords="offset points", xytext=(40,-3), ha='center')
plt.plot(df5['x [m]'], df5['y [m]'], color='tan', lw=0.8)
plt.annotate(f'(3, 3, 3.925)', (df5['x [m]'][0], df5['y [m]'][0]), textcoords="offset points", xytext=(10,5), ha='center')
plt.plot(df6['x [m]'], df6['y [m]'], 'y-', lw=0.8)
plt.annotate(f'(0, 3, 4.71)', (df6['x [m]'][0], df6['y [m]'][0]), textcoords="offset points", xytext=(0,8), ha='center')
plt.plot(df7['x [m]'], df7['y [m]'], 'k-', lw=0.8)
plt.annotate(f'(-3, 3, 5.495)', (df7['x [m]'][0], df7['y [m]'][0]), textcoords="offset points", xytext=(0,8), ha='center')
plt.plot(df8['x [m]'], df8['y [m]'], 'm-', lw=0.8)
plt.annotate(f'(-3, 0, 6.28)', (df8['x [m]'][0], df8['y [m]'][0]), textcoords="offset points", xytext=(-30,8), ha='center')
plt.scatter(df1['x [m]'].iloc[0], df1['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df2['x [m]'].iloc[0], df2['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df3['x [m]'].iloc[0], df3['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df4['x [m]'].iloc[0], df4['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df5['x [m]'].iloc[0], df5['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df6['x [m]'].iloc[0], df6['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df7['x [m]'].iloc[0], df7['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df8['x [m]'].iloc[0], df8['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df1['x [m]'].iloc[-1], df1['y [m]'].iloc[-1], marker='x', color='r')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.title('Trajectory')
plt.legend(['(x, y, initial angle'])
plt.grid()
plt.xlim(-5, 5)
plt.ylim(-5, 5)

plt.tight_layout()
plt.show()

# %%
# Plot settings
fig = plt.figure(figsize=(14, 10))

# Plot Trajectory (top-left)
plt.subplot(2, 2, 1)
plt.subplot(2, 2, 1)
plt.plot(df1['x [m]'], df1['y [m]'], 'b-', lw=0.8)
plt.annotate(f'(-3, -3, 0.785)', (df1['x [m]'][0], df1['y [m]'][0]), textcoords="offset points", xytext=(0,-20), ha='center')
plt.plot(df2['x [m]'], df2['y [m]'], 'g-', lw=0.8)
plt.annotate(f'(0, -3, 1.57)', (df2['x [m]'][0], df2['y [m]'][0]), textcoords="offset points", xytext=(-10,-20), ha='center')
plt.plot(df3['x [m]'], df3['y [m]'], 'r-', lw=0.8)
plt.annotate(f'(3, -3, 2.355)', (df3['x [m]'][0], df3['y [m]'][0]), textcoords="offset points", xytext=(10,-20), ha='center')
plt.plot(df4['x [m]'], df4['y [m]'], 'c-', lw=0.8)
plt.annotate(f'(3, 0, 3.14)', (df4['x [m]'][0], df4['y [m]'][0]), textcoords="offset points", xytext=(40,-3), ha='center')
plt.plot(df5['x [m]'], df5['y [m]'], color='tan', lw=0.8)
plt.annotate(f'(3, 3, 3.925)', (df5['x [m]'][0], df5['y [m]'][0]), textcoords="offset points", xytext=(10,5), ha='center')
plt.plot(df6['x [m]'], df6['y [m]'], 'y-', lw=0.8)
plt.annotate(f'(0, 3, 4.71)', (df6['x [m]'][0], df6['y [m]'][0]), textcoords="offset points", xytext=(0,8), ha='center')
plt.plot(df7['x [m]'], df7['y [m]'], 'k-', lw=0.8)
plt.annotate(f'(-3, 3, 5.495)', (df7['x [m]'][0], df7['y [m]'][0]), textcoords="offset points", xytext=(0,8), ha='center')
plt.plot(df8['x [m]'], df8['y [m]'], 'm-', lw=0.8)
plt.annotate(f'(-3, 0, 6.28)', (df8['x [m]'][0], df8['y [m]'][0]), textcoords="offset points", xytext=(-30,8), ha='center')
plt.scatter(df1['x [m]'].iloc[0], df1['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df2['x [m]'].iloc[0], df2['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df3['x [m]'].iloc[0], df3['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df4['x [m]'].iloc[0], df4['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df5['x [m]'].iloc[0], df5['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df6['x [m]'].iloc[0], df6['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df7['x [m]'].iloc[0], df7['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df8['x [m]'].iloc[0], df8['y [m]'].iloc[0], marker='o', color='lightgreen')
plt.scatter(df1['x [m]'].iloc[-1], df1['y [m]'].iloc[-1], marker='x', color='r')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.title('Trajectory')
# plt.legend()
plt.grid()
plt.xlim(-5, 5)
plt.ylim(-5, 5)

# Plot Norm and Alpha (top-right)
plt.subplot(2, 2, 2)
plt.plot(df1['t [s]'], np.linalg.norm([df1['x [m]'], df1['y [m]']], axis=0), 'b--', label=r'$\Vert(x,y)\Vert$ [m] (dt=0.1)')
plt.plot(df1['t [s]'], df1['alpha [rad]'], 'b-', label=r'$\alpha$ [rad] (dt=0.1)')
plt.plot(df2['t [s]'], np.linalg.norm([df2['x [m]'], df2['y [m]']], axis=0), 'g--', label=r'$\Vert(x,y)\Vert$ [m] (dt=0.2)')
plt.plot(df2['t [s]'], df2['alpha [rad]'], 'g-', label=r'$\alpha$ [rad] (dt=0.2)')
plt.plot(df3['t [s]'], np.linalg.norm([df3['x [m]'], df3['y [m]']], axis=0), 'r--', label=r'$\Vert(x,y)\Vert$ [m] (dt=0.3)')
plt.plot(df3['t [s]'], df3['alpha [rad]'], 'r-', label=r'$\alpha$ [rad] (dt=0.3)')
plt.plot(df4['t [s]'], np.linalg.norm([df4['x [m]'], df4['y [m]']], axis=0), 'c--', label=r'$\Vert(x,y)\Vert$ [m] (dt=0.5)')
plt.plot(df4['t [s]'], df4['alpha [rad]'], 'c-', label=r'$\alpha$ [rad] (dt=0.5)')
plt.plot(df5['t [s]'], np.linalg.norm([df5['x [m]'], df5['y [m]']], axis=0), 'm--', label=r'$\Vert(x,y)\Vert$ [m] (dt=1.0)')
plt.plot(df5['t [s]'], df5['alpha [rad]'], 'm-', label=r'$\alpha$ [rad] (dt=1.0)')
plt.xlabel('t [s]')
plt.title('Robot Solution')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.ylim(-11, 11)

# Plot Accumulated Cost
plt.subplot(2, 2, 3)
plt.plot(df1['t [s]'], df1['accum_obj'], 'b--', label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.1)')
plt.plot(df2['t [s]'], df2['accum_obj'], 'g--', label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.2)')
plt.plot(df3['t [s]'], df3['accum_obj'], 'r--', label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.3)')
plt.plot(df4['t [s]'], df4['accum_obj'], 'c--', label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=0.5)')
plt.plot(df5['t [s]'], df5['accum_obj'], 'm--', label=r'$\int \mathrm{Run.\,obj.} \,\mathrm{d}t$ (dt=1.0)')
plt.xlabel('t [s]')
plt.title('Cost Functions')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.yticks([10**i for i in range(2, 7)])  # Set y-axis ticks at powers of 10 from 10^0 to 10^6

# Plot Control inputs
plt.subplot(2, 2, 4)
plt.plot(df1['t [s]'], df1['v [m/s]'], 'b-', label='v [m/s] (dt=0.1)')
plt.plot(df1['t [s]'], df1['omega [rad/s]'], 'b--', label=r'$\omega$ [rad/s] (dt=0.1)')
plt.plot(df2['t [s]'], df2['v [m/s]'], 'g-', label='v [m/s] (dt=0.2)')
plt.plot(df2['t [s]'], df2['omega [rad/s]'], 'g--', label=r'$\omega$ [rad/s] (dt=0.2)')
plt.plot(df3['t [s]'], df3['v [m/s]'], 'r-', label='v [m/s] (dt=0.3)')
plt.plot(df3['t [s]'], df3['omega [rad/s]'], 'r--', label=r'$\omega$ [rad/s] (dt=0.3)')
plt.plot(df4['t [s]'], df4['v [m/s]'], 'c-', label='v [m/s] (dt=0.5)')
plt.plot(df4['t [s]'], df4['omega [rad/s]'], 'c--', label=r'$\omega$ [rad/s] (dt=0.5)')
plt.plot(df5['t [s]'], df5['v [m/s]'], 'm-', label='v [m/s] (dt=1.0)')
plt.plot(df5['t [s]'], df5['omega [rad/s]'], 'm--', label=r'$\omega$ [rad/s] (dt=1.0)')
plt.xlabel('t [s]')
plt.title('Control Input')
plt.legend()
plt.grid()
plt.xlim(0, 30)
plt.ylim(-4, 4)

plt.tight_layout()
plt.show()
